# %% [markdown]
# ## q-2-1: What are the number of parameters in 1st convolutional layers ?
#
#     Number of parameters= (filterHeight*filterWidth*prevChannels+Bias)*numFilters
#                             (5*5*1+1)*6 = 156

# %% [markdown]
# ## q-2-2: What are the number of parameters in pooling operation?
#
#     Pooling does not require any weight training So Zero(0)

# %% [markdown]
# ## q-2-3: Which of the following operations contain most number of parameters?
#     (c): Fully Connected Layer

# %% [markdown]
# ## q-2-4: Which operation consume most amount of memory?
#     (b): Fully Connected Layers at the end

# %% [markdown]
# ## q-2-5: Try different activation functions and describe observations.

# %%
print("Observations on RELU: ")
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
for i in range(5):
    img=Image.open("../output_data/layer"+str(i)+"RELU.png")
    plt.figure()
    plt.imshow(img)
# Out:
# Observations on RELU:

# %% [markdown]
#     Functions like SIGMOID and TANH outputs the values in range 0 to 1 & -1 to 1 which is almost a black color for an image perspective, so all of the images on SIGMOID are black.
